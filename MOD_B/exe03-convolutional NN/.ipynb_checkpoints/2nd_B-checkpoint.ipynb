# %%
# for the CNN
import numpy as np
import tensorflow.keras
import matplotlib.pyplot as plt
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
# Out:
# Using TensorFlow backend.

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000'
fnamex = 'DATA2/x_' + str0 + '.csv'
fnamey = 'DATA2/y_' + str0 + '.csv'

x = np.loadtxt(fnamex, delimiter = ',' ,dtype = float)
N = len(x)

# comment this part the first time
# without this the model is terrible
xm = x.mean(axis=1) # mean of each row
for n in range(N):
    x[n] = x[n] - xm[n] # we are shifted in the center, we are removing the mean
    
xstd = x.std(axis = 1) # standard deviation
for n in range(N):
    x[n] = x[n] / xstd[n]
    
    #now our data are whitin units

plt.plot(x[0])
plt.plot(x[1])
plt.plot(x[2])
plt.show()

categ = np.loadtxt(fnamey ,delimiter = ',', dtype = int)
N_categ = 3
y = np.zeros((N,N_categ))

for n in range(N):
    y[n][categ[n]] = 1.

perc_train = 0.8
N_train = int(N*perc_train)
N_val = N - N_train
x_train = x[:N_train]
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]

L = len(x[0])
print(N, N_train, N_val, L)
# Out:
# 10000 8000 2000 60

# %% [markdown]
# ### DATA reshaping

# %%
print('shape before: ',x_train.shape)
x_train = x_train.reshape(x_train.shape[0],L,1)
print('shape after: ',x_train.shape)
x_val = x_val.reshape(x_val.shape[0],L,1)
input_shape = (L,1)
# Out:
# shape before:  (8000, 60)
# shape after:  (8000, 60, 1)

# %% [markdown]
# ### Convolutional NN

# %%
from tensorflow.keras import initializers, regularizers

reg = regularizers.l1(0.1)
np.random.seed(12345)
ini = initializers.RandomNormal(mean = 0, stddev = 0.05)

model = Sequential()
model.add(Conv1D( filters = 5, kernel_size = 11,
                 kernel_regularizer = reg,
                 kernel_initializer = ini,
                 activation = 'relu',
                 input_shape = input_shape
                ))
model.add(AveragePooling1D(5))
model.add(Conv1D(filters = 5, kernel_size = 7, activation = 'relu'))
model.add(Flatten())
model.add(Dense(10, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(N_categ, activation = 'softmax' ))

print(model.summary())

from tensorflow.keras import optimizers

opt = optimizers.SGD(lr = 0.01, momentum = 0.9, nesterov = True, decay = 1e-6)

model.compile(loss = keras.losses.categorical_crossentropy,
             optimizer = 'adam', metrics = ['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 50, 5)             60
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 10, 5)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 4, 5)              180
# _________________________________________________________________
# flatten (Flatten)            (None, 20)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                210
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 483
# Trainable params: 483
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# After the shifting of the data, our model is working. 30 epochs are not enought

# %%
batch_size = 250
epochs = 250

fit = model.fit(x_train, y_train,
               batch_size = batch_size, epochs = epochs,
               validation_data = (x_val, y_val),
               verbose = 2, shuffle = True)
# Out:
# Epoch 1/250
# 32/32 - 1s - loss: 1.2868 - accuracy: 0.3674 - val_loss: 1.2227 - val_accuracy: 0.4090
# Epoch 2/250
# 32/32 - 0s - loss: 1.1806 - accuracy: 0.4036 - val_loss: 1.1441 - val_accuracy: 0.4095
# Epoch 3/250
# 32/32 - 0s - loss: 1.1253 - accuracy: 0.4026 - val_loss: 1.1103 - val_accuracy: 0.3765
# Epoch 4/250
# 32/32 - 0s - loss: 1.1045 - accuracy: 0.3974 - val_loss: 1.1002 - val_accuracy: 0.4385
# Epoch 5/250
# 32/32 - 0s - loss: 1.0997 - accuracy: 0.4100 - val_loss: 1.0977 - val_accuracy: 0.4525
# Epoch 6/250
# 32/32 - 0s - loss: 1.0975 - accuracy: 0.4182 - val_loss: 1.0934 - val_accuracy: 0.4660
# Epoch 7/250
# 32/32 - 0s - loss: 1.0920 - accuracy: 0.4305 - val_loss: 1.0857 - val_accuracy: 0.4590
# Epoch 8/250
# 32/32 - 0s - loss: 1.0825 - accuracy: 0.4417 - val_loss: 1.0675 - val_accuracy: 0.4755
# Epoch 9/250
# 32/32 - 0s - loss: 1.0635 - accuracy: 0.4509 - val_loss: 1.0458 - val_accuracy: 0.4860
# Epoch 10/250
# 32/32 - 0s - loss: 1.0437 - accuracy: 0.4694 - val_loss: 1.0201 - val_accuracy: 0.4980
# Epoch 11/250
# 32/32 - 0s - loss: 1.0233 - accuracy: 0.4821 - val_loss: 1.0025 - val_accuracy: 0.5080
# Epoch 12/250
# 32/32 - 0s - loss: 1.0137 - accuracy: 0.4837 - val_loss: 0.9936 - val_accuracy: 0.5075
# Epoch 13/250
# 32/32 - 0s - loss: 1.0003 - accuracy: 0.4969 - val_loss: 0.9870 - val_accuracy: 0.4975
# Epoch 14/250
# 32/32 - 0s - loss: 0.9926 - accuracy: 0.4989 - val_loss: 0.9786 - val_accuracy: 0.5100
# Epoch 15/250
# 32/32 - 0s - loss: 0.9893 - accuracy: 0.4996 - val_loss: 0.9617 - val_accuracy: 0.5195
# Epoch 16/250
# 32/32 - 0s - loss: 0.9824 - accuracy: 0.5061 - val_loss: 0.9597 - val_accuracy: 0.5170
# Epoch 17/250
# 32/32 - 0s - loss: 0.9878 - accuracy: 0.5095 - val_loss: 0.9624 - val_accuracy: 0.5115
# Epoch 18/250
# 32/32 - 0s - loss: 0.9740 - accuracy: 0.5125 - val_loss: 0.9532 - val_accuracy: 0.5385
# Epoch 19/250
# 32/32 - 0s - loss: 0.9729 - accuracy: 0.5121 - val_loss: 0.9510 - val_accuracy: 0.5275
# Epoch 20/250
# 32/32 - 0s - loss: 0.9701 - accuracy: 0.5116 - val_loss: 0.9566 - val_accuracy: 0.5180
# Epoch 21/250
# 32/32 - 0s - loss: 0.9701 - accuracy: 0.5101 - val_loss: 0.9520 - val_accuracy: 0.5445
# Epoch 22/250
# 32/32 - 0s - loss: 0.9649 - accuracy: 0.5220 - val_loss: 0.9450 - val_accuracy: 0.5440
# Epoch 23/250
# 32/32 - 0s - loss: 0.9603 - accuracy: 0.5138 - val_loss: 0.9436 - val_accuracy: 0.5420
# Epoch 24/250
# 32/32 - 0s - loss: 0.9635 - accuracy: 0.5228 - val_loss: 0.9430 - val_accuracy: 0.5235
# Epoch 25/250
# 32/32 - 0s - loss: 0.9573 - accuracy: 0.5215 - val_loss: 0.9446 - val_accuracy: 0.5315
# Epoch 26/250
# 32/32 - 0s - loss: 0.9611 - accuracy: 0.5181 - val_loss: 0.9444 - val_accuracy: 0.5595
# Epoch 27/250
# 32/32 - 0s - loss: 0.9630 - accuracy: 0.5217 - val_loss: 0.9402 - val_accuracy: 0.5480
# Epoch 28/250
# 32/32 - 0s - loss: 0.9572 - accuracy: 0.5260 - val_loss: 0.9362 - val_accuracy: 0.5400
# Epoch 29/250
# 32/32 - 0s - loss: 0.9557 - accuracy: 0.5228 - val_loss: 0.9392 - val_accuracy: 0.5640
# Epoch 30/250
# 32/32 - 0s - loss: 0.9566 - accuracy: 0.5188 - val_loss: 0.9387 - val_accuracy: 0.5530
# Epoch 31/250
# 32/32 - 0s - loss: 0.9518 - accuracy: 0.5311 - val_loss: 0.9367 - val_accuracy: 0.5705
# Epoch 32/250
# 32/32 - 0s - loss: 0.9510 - accuracy: 0.5303 - val_loss: 0.9351 - val_accuracy: 0.5555
# Epoch 33/250
# 32/32 - 0s - loss: 0.9505 - accuracy: 0.5219 - val_loss: 0.9331 - val_accuracy: 0.5755
# Epoch 34/250
# 32/32 - 0s - loss: 0.9530 - accuracy: 0.5299 - val_loss: 0.9387 - val_accuracy: 0.5530
# Epoch 35/250
# 32/32 - 0s - loss: 0.9515 - accuracy: 0.5420 - val_loss: 0.9356 - val_accuracy: 0.5265
# Epoch 36/250
# 32/32 - 0s - loss: 0.9496 - accuracy: 0.5353 - val_loss: 0.9307 - val_accuracy: 0.5630
# Epoch 37/250
# 32/32 - 0s - loss: 0.9456 - accuracy: 0.5305 - val_loss: 0.9307 - val_accuracy: 0.5540
# Epoch 38/250
# 32/32 - 0s - loss: 0.9441 - accuracy: 0.5471 - val_loss: 0.9366 - val_accuracy: 0.5260
# Epoch 39/250
# 32/32 - 0s - loss: 0.9447 - accuracy: 0.5412 - val_loss: 0.9276 - val_accuracy: 0.5685
# Epoch 40/250
# 32/32 - 0s - loss: 0.9433 - accuracy: 0.5462 - val_loss: 0.9347 - val_accuracy: 0.5235
# Epoch 41/250
# 32/32 - 0s - loss: 0.9406 - accuracy: 0.5493 - val_loss: 0.9244 - val_accuracy: 0.5605
# Epoch 42/250
# 32/32 - 0s - loss: 0.9401 - accuracy: 0.5530 - val_loss: 0.9566 - val_accuracy: 0.5175
# Epoch 43/250
# 32/32 - 0s - loss: 0.9429 - accuracy: 0.5481 - val_loss: 0.9391 - val_accuracy: 0.5525
# Epoch 44/250
# 32/32 - 0s - loss: 0.9464 - accuracy: 0.5406 - val_loss: 0.9222 - val_accuracy: 0.5640
# Epoch 45/250
# 32/32 - 0s - loss: 0.9405 - accuracy: 0.5536 - val_loss: 0.9469 - val_accuracy: 0.5315
# Epoch 46/250
# 32/32 - 0s - loss: 0.9415 - accuracy: 0.5474 - val_loss: 0.9508 - val_accuracy: 0.5220
# Epoch 47/250
# 32/32 - 0s - loss: 0.9377 - accuracy: 0.5527 - val_loss: 0.9196 - val_accuracy: 0.5395
# Epoch 48/250
# 32/32 - 0s - loss: 0.9375 - accuracy: 0.5523 - val_loss: 0.9241 - val_accuracy: 0.5475
# Epoch 49/250
# 32/32 - 0s - loss: 0.9377 - accuracy: 0.5564 - val_loss: 0.9262 - val_accuracy: 0.5575
# Epoch 50/250
# 32/32 - 0s - loss: 0.9303 - accuracy: 0.5564 - val_loss: 0.9102 - val_accuracy: 0.5730
# Epoch 51/250
# 32/32 - 0s - loss: 0.9291 - accuracy: 0.5595 - val_loss: 0.9121 - val_accuracy: 0.5560
# Epoch 52/250
# 32/32 - 0s - loss: 0.9296 - accuracy: 0.5574 - val_loss: 0.9082 - val_accuracy: 0.5770
# Epoch 53/250
# 32/32 - 0s - loss: 0.9294 - accuracy: 0.5614 - val_loss: 0.9145 - val_accuracy: 0.5755
# Epoch 54/250
# 32/32 - 0s - loss: 0.9271 - accuracy: 0.5667 - val_loss: 0.9075 - val_accuracy: 0.5890
# Epoch 55/250
# 32/32 - 0s - loss: 0.9213 - accuracy: 0.5695 - val_loss: 0.9103 - val_accuracy: 0.5825
# Epoch 56/250
# 32/32 - 0s - loss: 0.9256 - accuracy: 0.5719 - val_loss: 0.9084 - val_accuracy: 0.5910
# Epoch 57/250
# 32/32 - 0s - loss: 0.9172 - accuracy: 0.5727 - val_loss: 0.9188 - val_accuracy: 0.5885
# Epoch 58/250
# 32/32 - 0s - loss: 0.9174 - accuracy: 0.5685 - val_loss: 0.9155 - val_accuracy: 0.5555
# Epoch 59/250
# 32/32 - 0s - loss: 0.9147 - accuracy: 0.5816 - val_loss: 0.8940 - val_accuracy: 0.6055
# Epoch 60/250
# 32/32 - 0s - loss: 0.9174 - accuracy: 0.5776 - val_loss: 0.8891 - val_accuracy: 0.6135
# Epoch 61/250
# 32/32 - 0s - loss: 0.9141 - accuracy: 0.5805 - val_loss: 0.8956 - val_accuracy: 0.6015
# Epoch 62/250
# 32/32 - 0s - loss: 0.9056 - accuracy: 0.5886 - val_loss: 0.8920 - val_accuracy: 0.6095
# Epoch 63/250
# 32/32 - 0s - loss: 0.9076 - accuracy: 0.5853 - val_loss: 0.8909 - val_accuracy: 0.6180
# Epoch 64/250
# 32/32 - 0s - loss: 0.9041 - accuracy: 0.5935 - val_loss: 0.8816 - val_accuracy: 0.6195
# Epoch 65/250
# 32/32 - 0s - loss: 0.9016 - accuracy: 0.5928 - val_loss: 0.8809 - val_accuracy: 0.6075
# Epoch 66/250
# 32/32 - 0s - loss: 0.8971 - accuracy: 0.5991 - val_loss: 0.8843 - val_accuracy: 0.6055
# Epoch 67/250
# 32/32 - 0s - loss: 0.8974 - accuracy: 0.5984 - val_loss: 0.8705 - val_accuracy: 0.6305
# Epoch 68/250
# 32/32 - 0s - loss: 0.8906 - accuracy: 0.6058 - val_loss: 0.8670 - val_accuracy: 0.6270
# Epoch 69/250
# 32/32 - 0s - loss: 0.8875 - accuracy: 0.6065 - val_loss: 0.8671 - val_accuracy: 0.6375
# Epoch 70/250
# 32/32 - 0s - loss: 0.8889 - accuracy: 0.6076 - val_loss: 0.8638 - val_accuracy: 0.6355
# Epoch 71/250
# 32/32 - 0s - loss: 0.8837 - accuracy: 0.6105 - val_loss: 0.8768 - val_accuracy: 0.6110
# Epoch 72/250
# 32/32 - 0s - loss: 0.8818 - accuracy: 0.6077 - val_loss: 0.8590 - val_accuracy: 0.6345
# Epoch 73/250
# 32/32 - 0s - loss: 0.8815 - accuracy: 0.6129 - val_loss: 0.8573 - val_accuracy: 0.6365
# Epoch 74/250
# 32/32 - 0s - loss: 0.8860 - accuracy: 0.6114 - val_loss: 0.8556 - val_accuracy: 0.6445
# Epoch 75/250
# 32/32 - 0s - loss: 0.8770 - accuracy: 0.6204 - val_loss: 0.8531 - val_accuracy: 0.6355
# Epoch 76/250
# 32/32 - 0s - loss: 0.8672 - accuracy: 0.6216 - val_loss: 0.8546 - val_accuracy: 0.6320
# Epoch 77/250
# 32/32 - 0s - loss: 0.8735 - accuracy: 0.6187 - val_loss: 0.8534 - val_accuracy: 0.6390
# Epoch 78/250
# 32/32 - 0s - loss: 0.8708 - accuracy: 0.6145 - val_loss: 0.8406 - val_accuracy: 0.6620
# Epoch 79/250
# 32/32 - 0s - loss: 0.8651 - accuracy: 0.6259 - val_loss: 0.8470 - val_accuracy: 0.6355
# Epoch 80/250
# 32/32 - 0s - loss: 0.8617 - accuracy: 0.6271 - val_loss: 0.8563 - val_accuracy: 0.6405
# Epoch 81/250
# 32/32 - 0s - loss: 0.8751 - accuracy: 0.6242 - val_loss: 0.8363 - val_accuracy: 0.6645
# Epoch 82/250
# 32/32 - 0s - loss: 0.8588 - accuracy: 0.6369 - val_loss: 0.8363 - val_accuracy: 0.6620
# Epoch 83/250
# 32/32 - 0s - loss: 0.8568 - accuracy: 0.6329 - val_loss: 0.8460 - val_accuracy: 0.6520
# Epoch 84/250
# 32/32 - 0s - loss: 0.8545 - accuracy: 0.6382 - val_loss: 0.8317 - val_accuracy: 0.6585
# Epoch 85/250
# 32/32 - 0s - loss: 0.8528 - accuracy: 0.6403 - val_loss: 0.8292 - val_accuracy: 0.6535
# Epoch 86/250
# 32/32 - 0s - loss: 0.8508 - accuracy: 0.6369 - val_loss: 0.8273 - val_accuracy: 0.6625
# Epoch 87/250
# 32/32 - 0s - loss: 0.8458 - accuracy: 0.6416 - val_loss: 0.8294 - val_accuracy: 0.6610
# Epoch 88/250
# 32/32 - 0s - loss: 0.8676 - accuracy: 0.6230 - val_loss: 0.8617 - val_accuracy: 0.6295
# Epoch 89/250
# 32/32 - 0s - loss: 0.8593 - accuracy: 0.6335 - val_loss: 0.8216 - val_accuracy: 0.6680
# Epoch 90/250
# 32/32 - 0s - loss: 0.8418 - accuracy: 0.6396 - val_loss: 0.8223 - val_accuracy: 0.6620
# Epoch 91/250
# 32/32 - 0s - loss: 0.8485 - accuracy: 0.6396 - val_loss: 0.8181 - val_accuracy: 0.6660
# Epoch 92/250
# 32/32 - 0s - loss: 0.8440 - accuracy: 0.6428 - val_loss: 0.8156 - val_accuracy: 0.6700
# Epoch 93/250
# 32/32 - 0s - loss: 0.8380 - accuracy: 0.6494 - val_loss: 0.8229 - val_accuracy: 0.6610
# Epoch 94/250
# 32/32 - 0s - loss: 0.8399 - accuracy: 0.6415 - val_loss: 0.8170 - val_accuracy: 0.6650
# Epoch 95/250
# 32/32 - 0s - loss: 0.8368 - accuracy: 0.6470 - val_loss: 0.8509 - val_accuracy: 0.6255
# Epoch 96/250
# 32/32 - 0s - loss: 0.8425 - accuracy: 0.6506 - val_loss: 0.8238 - val_accuracy: 0.6550
# Epoch 97/250
# 32/32 - 0s - loss: 0.8347 - accuracy: 0.6532 - val_loss: 0.8109 - val_accuracy: 0.6770
# Epoch 98/250
# 32/32 - 0s - loss: 0.8384 - accuracy: 0.6515 - val_loss: 0.8344 - val_accuracy: 0.6340
# Epoch 99/250
# 32/32 - 0s - loss: 0.8379 - accuracy: 0.6424 - val_loss: 0.8190 - val_accuracy: 0.6600
# Epoch 100/250
# 32/32 - 0s - loss: 0.8380 - accuracy: 0.6505 - val_loss: 0.8079 - val_accuracy: 0.6785
# Epoch 101/250
# 32/32 - 0s - loss: 0.8297 - accuracy: 0.6504 - val_loss: 0.8071 - val_accuracy: 0.6745
# Epoch 102/250
# 32/32 - 0s - loss: 0.8357 - accuracy: 0.6529 - val_loss: 0.8038 - val_accuracy: 0.6735
# Epoch 103/250
# 32/32 - 0s - loss: 0.8291 - accuracy: 0.6551 - val_loss: 0.8033 - val_accuracy: 0.6800
# Epoch 104/250
# 32/32 - 0s - loss: 0.8332 - accuracy: 0.6491 - val_loss: 0.8104 - val_accuracy: 0.6700
# Epoch 105/250
# 32/32 - 0s - loss: 0.8293 - accuracy: 0.6501 - val_loss: 0.8100 - val_accuracy: 0.6655
# Epoch 106/250
# 32/32 - 0s - loss: 0.8282 - accuracy: 0.6582 - val_loss: 0.8169 - val_accuracy: 0.6630
# Epoch 107/250
# 32/32 - 0s - loss: 0.8293 - accuracy: 0.6519 - val_loss: 0.7989 - val_accuracy: 0.6815
# Epoch 108/250
# 32/32 - 0s - loss: 0.8223 - accuracy: 0.6538 - val_loss: 0.8050 - val_accuracy: 0.6770
# Epoch 109/250
# 32/32 - 0s - loss: 0.8175 - accuracy: 0.6640 - val_loss: 0.7994 - val_accuracy: 0.6780
# Epoch 110/250
# 32/32 - 0s - loss: 0.8256 - accuracy: 0.6515 - val_loss: 0.8050 - val_accuracy: 0.6765
# Epoch 111/250
# 32/32 - 0s - loss: 0.8217 - accuracy: 0.6601 - val_loss: 0.7998 - val_accuracy: 0.6705
# Epoch 112/250
# 32/32 - 0s - loss: 0.8274 - accuracy: 0.6521 - val_loss: 0.7994 - val_accuracy: 0.6690
# Epoch 113/250
# 32/32 - 0s - loss: 0.8216 - accuracy: 0.6594 - val_loss: 0.8053 - val_accuracy: 0.6755
# Epoch 114/250
# 32/32 - 0s - loss: 0.8116 - accuracy: 0.6639 - val_loss: 0.8054 - val_accuracy: 0.6665
# Epoch 115/250
# 32/32 - 0s - loss: 0.8193 - accuracy: 0.6695 - val_loss: 0.7979 - val_accuracy: 0.6760
# Epoch 116/250
# 32/32 - 0s - loss: 0.8141 - accuracy: 0.6606 - val_loss: 0.7907 - val_accuracy: 0.6845
# Epoch 117/250
# 32/32 - 0s - loss: 0.8342 - accuracy: 0.6522 - val_loss: 0.8094 - val_accuracy: 0.6570
# Epoch 118/250
# 32/32 - 0s - loss: 0.8173 - accuracy: 0.6637 - val_loss: 0.7974 - val_accuracy: 0.6785
# Epoch 119/250
# 32/32 - 0s - loss: 0.8181 - accuracy: 0.6622 - val_loss: 0.7918 - val_accuracy: 0.6825
# Epoch 120/250
# 32/32 - 0s - loss: 0.8111 - accuracy: 0.6693 - val_loss: 0.7948 - val_accuracy: 0.6740
# Epoch 121/250
# 32/32 - 0s - loss: 0.8141 - accuracy: 0.6599 - val_loss: 0.7854 - val_accuracy: 0.6890
# Epoch 122/250
# 32/32 - 0s - loss: 0.8108 - accuracy: 0.6669 - val_loss: 0.7856 - val_accuracy: 0.6820
# Epoch 123/250
# 32/32 - 0s - loss: 0.8167 - accuracy: 0.6653 - val_loss: 0.8134 - val_accuracy: 0.6570
# Epoch 124/250
# 32/32 - 0s - loss: 0.8126 - accuracy: 0.6634 - val_loss: 0.7830 - val_accuracy: 0.6845
# Epoch 125/250
# 32/32 - 0s - loss: 0.8073 - accuracy: 0.6780 - val_loss: 0.7974 - val_accuracy: 0.6730
# Epoch 126/250
# 32/32 - 0s - loss: 0.8101 - accuracy: 0.6661 - val_loss: 0.8157 - val_accuracy: 0.6580
# Epoch 127/250
# 32/32 - 0s - loss: 0.8085 - accuracy: 0.6661 - val_loss: 0.7873 - val_accuracy: 0.6835
# Epoch 128/250
# 32/32 - 0s - loss: 0.8178 - accuracy: 0.6641 - val_loss: 0.8294 - val_accuracy: 0.6320
# Epoch 129/250
# 32/32 - 0s - loss: 0.8085 - accuracy: 0.6659 - val_loss: 0.8139 - val_accuracy: 0.6630
# Epoch 130/250
# 32/32 - 0s - loss: 0.8092 - accuracy: 0.6699 - val_loss: 0.7892 - val_accuracy: 0.6740
# Epoch 131/250
# 32/32 - 0s - loss: 0.8003 - accuracy: 0.6745 - val_loss: 0.7877 - val_accuracy: 0.6850
# Epoch 132/250
# 32/32 - 0s - loss: 0.8110 - accuracy: 0.6675 - val_loss: 0.7814 - val_accuracy: 0.6890
# Epoch 133/250
# 32/32 - 0s - loss: 0.8105 - accuracy: 0.6633 - val_loss: 0.8041 - val_accuracy: 0.6715
# Epoch 134/250
# 32/32 - 0s - loss: 0.8047 - accuracy: 0.6716 - val_loss: 0.7901 - val_accuracy: 0.6710
# Epoch 135/250
# 32/32 - 0s - loss: 0.8024 - accuracy: 0.6716 - val_loss: 0.7941 - val_accuracy: 0.6760
# Epoch 136/250
# 32/32 - 0s - loss: 0.8016 - accuracy: 0.6734 - val_loss: 0.7935 - val_accuracy: 0.6780
# Epoch 137/250
# 32/32 - 0s - loss: 0.8055 - accuracy: 0.6705 - val_loss: 0.8196 - val_accuracy: 0.6630
# Epoch 138/250
# 32/32 - 0s - loss: 0.8078 - accuracy: 0.6714 - val_loss: 0.7980 - val_accuracy: 0.6655
# Epoch 139/250
# 32/32 - 0s - loss: 0.8045 - accuracy: 0.6693 - val_loss: 0.7806 - val_accuracy: 0.6820
# Epoch 140/250
# 32/32 - 0s - loss: 0.7996 - accuracy: 0.6721 - val_loss: 0.8013 - val_accuracy: 0.6695
# Epoch 141/250
# 32/32 - 0s - loss: 0.8019 - accuracy: 0.6685 - val_loss: 0.7822 - val_accuracy: 0.6795
# Epoch 142/250
# 32/32 - 0s - loss: 0.8000 - accuracy: 0.6741 - val_loss: 0.7820 - val_accuracy: 0.6815
# Epoch 143/250
# 32/32 - 0s - loss: 0.8033 - accuracy: 0.6683 - val_loss: 0.7783 - val_accuracy: 0.6805
# Epoch 144/250
# 32/32 - 0s - loss: 0.7955 - accuracy: 0.6737 - val_loss: 0.7896 - val_accuracy: 0.6740
# Epoch 145/250
# 32/32 - 0s - loss: 0.8021 - accuracy: 0.6756 - val_loss: 0.7904 - val_accuracy: 0.6740
# Epoch 146/250
# 32/32 - 0s - loss: 0.7937 - accuracy: 0.6815 - val_loss: 0.7788 - val_accuracy: 0.6805
# Epoch 147/250
# 32/32 - 0s - loss: 0.7965 - accuracy: 0.6765 - val_loss: 0.7827 - val_accuracy: 0.6665
# Epoch 148/250
# 32/32 - 0s - loss: 0.8009 - accuracy: 0.6708 - val_loss: 0.7911 - val_accuracy: 0.6620
# Epoch 149/250
# 32/32 - 0s - loss: 0.7930 - accuracy: 0.6765 - val_loss: 0.7694 - val_accuracy: 0.6925
# Epoch 150/250
# 32/32 - 0s - loss: 0.7936 - accuracy: 0.6796 - val_loss: 0.7792 - val_accuracy: 0.6840
# Epoch 151/250
# 32/32 - 0s - loss: 0.8034 - accuracy: 0.6780 - val_loss: 0.7710 - val_accuracy: 0.6905
# Epoch 152/250
# 32/32 - 0s - loss: 0.8046 - accuracy: 0.6701 - val_loss: 0.7761 - val_accuracy: 0.6870
# Epoch 153/250
# 32/32 - 0s - loss: 0.7912 - accuracy: 0.6836 - val_loss: 0.7703 - val_accuracy: 0.6870
# Epoch 154/250
# 32/32 - 0s - loss: 0.7945 - accuracy: 0.6779 - val_loss: 0.7679 - val_accuracy: 0.6950
# Epoch 155/250
# 32/32 - 0s - loss: 0.7903 - accuracy: 0.6817 - val_loss: 0.7821 - val_accuracy: 0.6820
# Epoch 156/250
# 32/32 - 0s - loss: 0.7954 - accuracy: 0.6721 - val_loss: 0.7663 - val_accuracy: 0.6970
# Epoch 157/250
# 32/32 - 0s - loss: 0.7971 - accuracy: 0.6730 - val_loss: 0.7975 - val_accuracy: 0.6645
# Epoch 158/250
# 32/32 - 0s - loss: 0.7930 - accuracy: 0.6754 - val_loss: 0.7776 - val_accuracy: 0.6710
# Epoch 159/250
# 32/32 - 0s - loss: 0.7921 - accuracy: 0.6809 - val_loss: 0.8144 - val_accuracy: 0.6560
# Epoch 160/250
# 32/32 - 0s - loss: 0.7964 - accuracy: 0.6737 - val_loss: 0.7837 - val_accuracy: 0.6775
# Epoch 161/250
# 32/32 - 0s - loss: 0.7830 - accuracy: 0.6892 - val_loss: 0.7689 - val_accuracy: 0.6825
# Epoch 162/250
# 32/32 - 0s - loss: 0.7859 - accuracy: 0.6833 - val_loss: 0.7656 - val_accuracy: 0.6955
# Epoch 163/250
# 32/32 - 0s - loss: 0.7869 - accuracy: 0.6815 - val_loss: 0.7809 - val_accuracy: 0.6745
# Epoch 164/250
# 32/32 - 0s - loss: 0.7914 - accuracy: 0.6770 - val_loss: 0.8074 - val_accuracy: 0.6555
# Epoch 165/250
# 32/32 - 0s - loss: 0.7954 - accuracy: 0.6795 - val_loss: 0.7654 - val_accuracy: 0.6880
# Epoch 166/250
# 32/32 - 0s - loss: 0.7942 - accuracy: 0.6760 - val_loss: 0.7716 - val_accuracy: 0.6810
# Epoch 167/250
# 32/32 - 0s - loss: 0.7951 - accuracy: 0.6758 - val_loss: 0.7615 - val_accuracy: 0.6960
# Epoch 168/250
# 32/32 - 0s - loss: 0.7822 - accuracy: 0.6829 - val_loss: 0.7641 - val_accuracy: 0.6930
# Epoch 169/250
# 32/32 - 0s - loss: 0.7844 - accuracy: 0.6821 - val_loss: 0.7643 - val_accuracy: 0.6915
# Epoch 170/250
# 32/32 - 0s - loss: 0.7819 - accuracy: 0.6824 - val_loss: 0.7649 - val_accuracy: 0.6905
# Epoch 171/250
# 32/32 - 0s - loss: 0.7891 - accuracy: 0.6816 - val_loss: 0.7835 - val_accuracy: 0.6760
# Epoch 172/250
# 32/32 - 0s - loss: 0.7915 - accuracy: 0.6741 - val_loss: 0.7654 - val_accuracy: 0.6855
# Epoch 173/250
# 32/32 - 0s - loss: 0.7878 - accuracy: 0.6837 - val_loss: 0.7723 - val_accuracy: 0.6785
# Epoch 174/250
# 32/32 - 0s - loss: 0.7821 - accuracy: 0.6862 - val_loss: 0.7700 - val_accuracy: 0.6815
# Epoch 175/250
# 32/32 - 0s - loss: 0.7863 - accuracy: 0.6831 - val_loss: 0.7603 - val_accuracy: 0.6980
# Epoch 176/250
# 32/32 - 0s - loss: 0.7862 - accuracy: 0.6824 - val_loss: 0.7608 - val_accuracy: 0.6940
# Epoch 177/250
# 32/32 - 0s - loss: 0.7805 - accuracy: 0.6859 - val_loss: 0.7787 - val_accuracy: 0.6770
# Epoch 178/250
# 32/32 - 0s - loss: 0.7859 - accuracy: 0.6830 - val_loss: 0.8010 - val_accuracy: 0.6640
# Epoch 179/250
# 32/32 - 0s - loss: 0.7924 - accuracy: 0.6737 - val_loss: 0.7640 - val_accuracy: 0.6910
# Epoch 180/250
# 32/32 - 0s - loss: 0.7779 - accuracy: 0.6831 - val_loss: 0.7578 - val_accuracy: 0.6970
# Epoch 181/250
# 32/32 - 0s - loss: 0.7812 - accuracy: 0.6833 - val_loss: 0.7581 - val_accuracy: 0.6885
# Epoch 182/250
# 32/32 - 0s - loss: 0.7735 - accuracy: 0.6871 - val_loss: 0.7752 - val_accuracy: 0.6785
# Epoch 183/250
# 32/32 - 0s - loss: 0.7900 - accuracy: 0.6784 - val_loss: 0.7711 - val_accuracy: 0.6885
# Epoch 184/250
# 32/32 - 0s - loss: 0.7769 - accuracy: 0.6914 - val_loss: 0.7708 - val_accuracy: 0.6755
# Epoch 185/250
# 32/32 - 0s - loss: 0.7741 - accuracy: 0.6876 - val_loss: 0.7795 - val_accuracy: 0.6750
# Epoch 186/250
# 32/32 - 0s - loss: 0.8013 - accuracy: 0.6594 - val_loss: 0.8391 - val_accuracy: 0.6310
# Epoch 187/250
# 32/32 - 0s - loss: 0.7852 - accuracy: 0.6861 - val_loss: 0.7567 - val_accuracy: 0.6980
# Epoch 188/250
# 32/32 - 0s - loss: 0.7757 - accuracy: 0.6862 - val_loss: 0.7643 - val_accuracy: 0.6950
# Epoch 189/250
# 32/32 - 0s - loss: 0.7720 - accuracy: 0.6940 - val_loss: 0.7699 - val_accuracy: 0.6760
# Epoch 190/250
# 32/32 - 0s - loss: 0.7711 - accuracy: 0.6936 - val_loss: 0.7767 - val_accuracy: 0.6690
# Epoch 191/250
# 32/32 - 0s - loss: 0.7749 - accuracy: 0.6904 - val_loss: 0.7520 - val_accuracy: 0.6965
# Epoch 192/250
# 32/32 - 0s - loss: 0.7712 - accuracy: 0.6896 - val_loss: 0.7556 - val_accuracy: 0.6875
# Epoch 193/250
# 32/32 - 0s - loss: 0.7794 - accuracy: 0.6854 - val_loss: 0.7609 - val_accuracy: 0.6825
# Epoch 194/250
# 32/32 - 0s - loss: 0.7770 - accuracy: 0.6906 - val_loss: 0.7670 - val_accuracy: 0.6830
# Epoch 195/250
# 32/32 - 0s - loss: 0.7749 - accuracy: 0.6884 - val_loss: 0.7524 - val_accuracy: 0.6950
# Epoch 196/250
# 32/32 - 0s - loss: 0.7692 - accuracy: 0.6965 - val_loss: 0.7679 - val_accuracy: 0.6835
# Epoch 197/250
# 32/32 - 0s - loss: 0.7727 - accuracy: 0.6883 - val_loss: 0.7553 - val_accuracy: 0.6940
# Epoch 198/250
# 32/32 - 0s - loss: 0.7760 - accuracy: 0.6924 - val_loss: 0.7508 - val_accuracy: 0.6950
# Epoch 199/250
# 32/32 - 0s - loss: 0.7722 - accuracy: 0.6891 - val_loss: 0.7546 - val_accuracy: 0.6885
# Epoch 200/250
# 32/32 - 0s - loss: 0.7720 - accuracy: 0.6841 - val_loss: 0.7496 - val_accuracy: 0.6960
# Epoch 201/250
# 32/32 - 0s - loss: 0.7689 - accuracy: 0.6866 - val_loss: 0.7799 - val_accuracy: 0.6600
# Epoch 202/250
# 32/32 - 0s - loss: 0.7886 - accuracy: 0.6856 - val_loss: 0.7694 - val_accuracy: 0.6780
# Epoch 203/250
# 32/32 - 0s - loss: 0.7706 - accuracy: 0.6934 - val_loss: 0.7584 - val_accuracy: 0.6905
# Epoch 204/250
# 32/32 - 0s - loss: 0.7778 - accuracy: 0.6798 - val_loss: 0.7469 - val_accuracy: 0.7025
# Epoch 205/250
# 32/32 - 0s - loss: 0.7768 - accuracy: 0.6839 - val_loss: 0.7590 - val_accuracy: 0.6965
# Epoch 206/250
# 32/32 - 0s - loss: 0.7734 - accuracy: 0.6905 - val_loss: 0.7609 - val_accuracy: 0.6820
# Epoch 207/250
# 32/32 - 0s - loss: 0.7660 - accuracy: 0.6901 - val_loss: 0.7621 - val_accuracy: 0.6830
# Epoch 208/250
# 32/32 - 0s - loss: 0.7880 - accuracy: 0.6725 - val_loss: 0.7955 - val_accuracy: 0.6580
# Epoch 209/250
# 32/32 - 0s - loss: 0.7802 - accuracy: 0.6801 - val_loss: 0.7596 - val_accuracy: 0.6805
# Epoch 210/250
# 32/32 - 0s - loss: 0.7903 - accuracy: 0.6768 - val_loss: 0.7653 - val_accuracy: 0.6850
# Epoch 211/250
# 32/32 - 0s - loss: 0.7797 - accuracy: 0.6871 - val_loss: 0.7690 - val_accuracy: 0.6825
# Epoch 212/250
# 32/32 - 0s - loss: 0.7683 - accuracy: 0.6904 - val_loss: 0.7589 - val_accuracy: 0.6790
# Epoch 213/250
# 32/32 - 0s - loss: 0.7668 - accuracy: 0.6925 - val_loss: 0.7464 - val_accuracy: 0.6985
# Epoch 214/250
# 32/32 - 0s - loss: 0.7749 - accuracy: 0.6871 - val_loss: 0.7687 - val_accuracy: 0.6805
# Epoch 215/250
# 32/32 - 0s - loss: 0.7818 - accuracy: 0.6840 - val_loss: 0.7496 - val_accuracy: 0.6875
# Epoch 216/250
# 32/32 - 0s - loss: 0.7674 - accuracy: 0.6941 - val_loss: 0.7450 - val_accuracy: 0.6985
# Epoch 217/250
# 32/32 - 0s - loss: 0.7627 - accuracy: 0.7015 - val_loss: 0.7440 - val_accuracy: 0.6985
# Epoch 218/250
# 32/32 - 0s - loss: 0.7726 - accuracy: 0.6951 - val_loss: 0.7623 - val_accuracy: 0.6795
# Epoch 219/250
# 32/32 - 0s - loss: 0.7674 - accuracy: 0.6911 - val_loss: 0.7565 - val_accuracy: 0.6915
# Epoch 220/250
# 32/32 - 0s - loss: 0.7645 - accuracy: 0.6921 - val_loss: 0.7570 - val_accuracy: 0.6850
# Epoch 221/250
# 32/32 - 0s - loss: 0.7692 - accuracy: 0.6898 - val_loss: 0.7587 - val_accuracy: 0.6775
# Epoch 222/250
# 32/32 - 0s - loss: 0.7679 - accuracy: 0.6929 - val_loss: 0.7751 - val_accuracy: 0.6665
# Epoch 223/250
# 32/32 - 0s - loss: 0.7752 - accuracy: 0.6860 - val_loss: 0.7466 - val_accuracy: 0.6980
# Epoch 224/250
# 32/32 - 0s - loss: 0.7598 - accuracy: 0.6961 - val_loss: 0.7601 - val_accuracy: 0.6840
# Epoch 225/250
# 32/32 - 0s - loss: 0.7740 - accuracy: 0.6848 - val_loss: 0.7473 - val_accuracy: 0.6945
# Epoch 226/250
# 32/32 - 0s - loss: 0.7661 - accuracy: 0.6904 - val_loss: 0.7450 - val_accuracy: 0.6960
# Epoch 227/250
# 32/32 - 0s - loss: 0.7625 - accuracy: 0.6984 - val_loss: 0.7456 - val_accuracy: 0.6985
# Epoch 228/250
# 32/32 - 0s - loss: 0.7726 - accuracy: 0.6845 - val_loss: 0.7538 - val_accuracy: 0.6880
# Epoch 229/250
# 32/32 - 0s - loss: 0.7700 - accuracy: 0.6909 - val_loss: 0.7412 - val_accuracy: 0.6965
# Epoch 230/250
# 32/32 - 0s - loss: 0.7699 - accuracy: 0.6913 - val_loss: 0.7452 - val_accuracy: 0.6945
# Epoch 231/250
# 32/32 - 0s - loss: 0.7887 - accuracy: 0.6777 - val_loss: 0.7657 - val_accuracy: 0.6755
# Epoch 232/250
# 32/32 - 0s - loss: 0.7762 - accuracy: 0.6816 - val_loss: 0.7863 - val_accuracy: 0.6485
# Epoch 233/250
# 32/32 - 0s - loss: 0.7755 - accuracy: 0.6816 - val_loss: 0.7563 - val_accuracy: 0.6865
# Epoch 234/250
# 32/32 - 0s - loss: 0.7564 - accuracy: 0.7010 - val_loss: 0.7458 - val_accuracy: 0.6930
# Epoch 235/250
# 32/32 - 0s - loss: 0.7643 - accuracy: 0.6946 - val_loss: 0.7399 - val_accuracy: 0.7000
# Epoch 236/250
# 32/32 - 0s - loss: 0.7646 - accuracy: 0.6915 - val_loss: 0.7681 - val_accuracy: 0.6730
# Epoch 237/250
# 32/32 - 0s - loss: 0.7635 - accuracy: 0.6954 - val_loss: 0.7517 - val_accuracy: 0.6960
# Epoch 238/250
# 32/32 - 0s - loss: 0.7631 - accuracy: 0.6925 - val_loss: 0.7397 - val_accuracy: 0.7015
# Epoch 239/250
# 32/32 - 0s - loss: 0.7633 - accuracy: 0.6906 - val_loss: 0.7923 - val_accuracy: 0.6605
# Epoch 240/250
# 32/32 - 0s - loss: 0.7760 - accuracy: 0.6859 - val_loss: 0.7506 - val_accuracy: 0.6845
# Epoch 241/250
# 32/32 - 0s - loss: 0.7694 - accuracy: 0.6880 - val_loss: 0.7410 - val_accuracy: 0.7035
# Epoch 242/250
# 32/32 - 0s - loss: 0.7573 - accuracy: 0.7019 - val_loss: 0.7473 - val_accuracy: 0.6955
# Epoch 243/250
# 32/32 - 0s - loss: 0.7545 - accuracy: 0.7009 - val_loss: 0.7605 - val_accuracy: 0.6760
# Epoch 244/250
# 32/32 - 0s - loss: 0.7592 - accuracy: 0.7015 - val_loss: 0.7421 - val_accuracy: 0.7005
# Epoch 245/250
# 32/32 - 0s - loss: 0.7600 - accuracy: 0.6929 - val_loss: 0.7483 - val_accuracy: 0.6915
# Epoch 246/250
# 32/32 - 0s - loss: 0.7698 - accuracy: 0.6883 - val_loss: 0.7508 - val_accuracy: 0.6825
# Epoch 247/250
# 32/32 - 0s - loss: 0.7588 - accuracy: 0.6994 - val_loss: 0.7475 - val_accuracy: 0.6920
# Epoch 248/250
# 32/32 - 0s - loss: 0.7589 - accuracy: 0.6967 - val_loss: 0.7481 - val_accuracy: 0.6900
# Epoch 249/250
# 32/32 - 0s - loss: 0.7540 - accuracy: 0.7030 - val_loss: 0.7447 - val_accuracy: 0.6975
# Epoch 250/250
# 32/32 - 0s - loss: 0.7713 - accuracy: 0.6899 - val_loss: 0.7514 - val_accuracy: 0.6870

# %%
for obs in ('accuracy', 'loss'):
    plt.figure(figsize = (6,4))
    plt.plot(fit.history[obs], 'r', label = obs +' of training data')
    
    plt.plot(fit.history['val_' + obs], 'b--', label = obs + ' of validation data')
    plt.title('Adam')
    plt.ylabel(obs)
    plt.xlabel('epochs')
    plt.legend()
    plt.show()

# %%
print(keras.__version__)
print(tensorflow.__version__)
# Out:
# 2.4.0
# 2.4.1
